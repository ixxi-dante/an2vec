# %% [markdown]
# # GCNAE: capturing feature-network dependencies

# %% [markdown]
# ## Imports and setup

# %%
import time
import random
import os
import itertools

import numpy as np
import scipy as sp
import scipy.stats
import sklearn.preprocessing
import matplotlib.pyplot as plt
import seaborn as sb
import networkx as nx

import keras
from keras import backend as K
import tensorflow as tf
from tensorflow.python import debug as tf_debug
from keras.utils.vis_utils import model_to_dot
from keras_tqdm import TQDMNotebookCallback as TQDMCallback

from progressbar import ProgressBar
from IPython.display import SVG, HTML, display

from nw2vec import ae
from nw2vec import utils
from nw2vec import codecs
from nw2vec import layers
from nw2vec import viz
from nw2vec import batching

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
MODEL_NAME = 'vae-explore'

# %%
random.seed(1)
np.random.seed(1)

# %% [markdown]
# ### Model drawing routines

# %%
def plot_ξ_distribution(glk, q_model, q_codecs, adj, features):
    g, l, k = glk
    palette = np.concatenate([np.array(sb.color_palette(n_colors=l)),
                              .5 * np.ones((l, 1))],
                             axis=1)
    communities = ([[i] for i in range(l)] * np.ones((l, k), dtype=np.int32)).reshape(-1)
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))#, sharex=True, sharey=True)

    x, _, feeds = next(batching.batches(vae, adj, features, target_func,
                                        adj.shape[0], 1,
                                        p=1, q=1, neighbour_samples=None))
    q_pred = q_model.predict_on_fed_batch(x, feeds=feeds)

    # KDE plots
    assert len(q_codecs) == 1
    q_pred_ξ_sample = K.eval(codecs.available_codecs()[q_codecs[0]](q_pred).stochastic_value(100))
    for i in range(l):
        x = q_pred_ξ_sample[i * k:(i + 1) * k, :, 0].flatten()
        y = q_pred_ξ_sample[i * k:(i + 1) * k, :, 1].flatten()
        sb.kdeplot(x, y, cmap=sb.light_palette(palette[i], as_cmap=True),
                   shade=True, shade_lowest=False, ax=ax1)
    ax1.set_title(r'$\xi$ density for each community (flat nodes+sampling)')
    
    # μ plots
    q_pred_μ = q_pred[:, :2].T
    ax2.scatter(q_pred_μ[0], q_pred_μ[1], s=250, c=palette[communities])
    for i, (x, y) in enumerate(q_pred_μ.T):
        ax2.text(x, y, str(i), ha='center', va='center', color='white')
    ax2.set_title(r'$\mu = \left<\xi\right>$ for each node')
    
    # Box representing the μ plots in the KDE plots
    ax1.hlines(ax2.get_ylim(), *ax2.get_xlim(), colors='lightgrey')
    ax1.vlines(ax2.get_xlim(), *ax2.get_ylim(), colors='lightgrey')

# %% [markdown]
# ## Test graphs

# %%
# Parameters
l = 8
k = 10
p_in = .4
p_out = .01
g = nx.planted_partition_graph(l, k, p_in, p_out)

# Show the graph
labels = np.zeros((l * k, l), dtype=np.float32)
for c in range(l):
    labels[range(c * k, (c + 1) * k), c] = 1
viz.draw_network(g, labels=labels);

# %% [markdown]
# - three feature communities, shifted from network communities
# - ✔ comms 1 & 2 have 1 0 0 0 0, comms 3, 4, 5 have 0 1 0 0 0, + .1 gaussian noise
# - ✔ same, but with an `eye` added to the features
# - ✔ same, but shear in the middle of comm 3
# - ✔ one-hot that is shifted from network structure
# - ✔ one-hot that is finer than network structure
# - several ones (random # and random position) for all nodes:
#   - ✔ random
#   - ✔ correlated with comms
#   - ✔ finer than comms
#   - ✔ grosser than comms

# %%
labels = np.zeros((l * k, 3), dtype=np.float32)
labels[:25, 0] = 1
labels[25:55, 1] = 1
labels[55:, 2] = 1

noisy_labels = labels + np.random.normal(loc=0.0, scale=.1, size=labels.shape)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(5, 5))

im1 = ax1.imshow(labels)
plt.colorbar(im1, ax=ax1)

im2 = ax2.imshow(noisy_labels)
plt.colorbar(im2, ax=ax2)

# %%
viz.draw_network(g, labels=noisy_labels);

# %% [markdown]
# ## Build the VAE

# %%
# VAE Parameters
n_nodes = l * k
adj = nx.adjacency_matrix(g).astype(np.float32)

n_ξ_samples = 5
dim_data, dim_l1, dim_ξ = labels.shape[1], 10, 2
dims = (dim_data, dim_l1, dim_ξ)
use_bias = False


# Actual VAE
def build_q(dims, use_bias=False):
    dim_data, dim_l1, dim_ξ = dims

    q_input = keras.layers.Input(shape=(dim_data,), name='q_input')
    # CANDO: change activation
    q_layer1_placeholders, q_layer1 = ae.gc_layer_with_placeholders(
        dim_l1, 'q_layer1', {'use_bias': use_bias, 'activation': 'relu'}, q_input)
    q_μ_flat_placeholders, q_μ_flat = ae.gc_layer_with_placeholders(
        dim_ξ, 'q_mu_flat', {'use_bias': use_bias, 'gather_mask': True}, q_layer1)
    q_logD_flat_placeholders, q_logD_flat = ae.gc_layer_with_placeholders(
        dim_ξ, 'q_logD_flat', {'use_bias': use_bias, 'gather_mask': True}, q_layer1)
    q_μlogD_flat = keras.layers.Concatenate(name='q_mulogD_flat')(
        [q_μ_flat, q_logD_flat])
    q_model = ae.Model(inputs=([q_input]
                               + q_layer1_placeholders
                               + q_μ_flat_placeholders
                               + q_logD_flat_placeholders),
                       outputs=q_μlogD_flat)

    return q_model, ('OrthogonalGaussian',)

q_model, q_codecs = build_q(dims, use_bias=use_bias)

def p_builder(p_input):
    # CANDO: change activation
    p_layer1 = keras.layers.Dense(dim_l1, use_bias=use_bias, activation='relu',
                                  kernel_regularizer='l2', bias_regularizer='l2',
                                  name='p_layer1')(p_input)
    p_adj = layers.Bilinear(0, use_bias=use_bias,
                            kernel_regularizer='l2', bias_regularizer='l2',
                            name='p_adj')([p_layer1, p_layer1])
    p_v = keras.layers.Dense(dim_data, use_bias=use_bias,
                             kernel_regularizer='l2', bias_regularizer='l2',
                             name='p_v')(p_layer1)
    return ([p_adj, p_v], ('SigmoidBernoulliScaledAdjacency', 'SigmoidBernoulli'))

vae, vae_codecs = ae.build_vae(
    (q_model, q_codecs),
    p_builder,
    n_ξ_samples,
    [
        1.0,  # q
        1.999,  # adj
        .001   # p
    ]
)

# %%
display(SVG(model_to_dot(vae, rankdir='LR').create(prog='dot', format='svg')))

# %% [markdown]
# ## Target function

# %%
def target_func(batch_adj, required_nodes, final_nodes):
    return [
        np.zeros(1), # ignored
        utils.expand_dims_tile(utils.expand_dims_tile(batch_adj + np.eye(batch_adj.shape[0]), 0, n_ξ_samples), 0, 1),
        utils.expand_dims_tile(labels[final_nodes], 1, n_ξ_samples),
    ]

input_features = noisy_labels

# %% [markdown]
# ## Before training
#
# $\xi$ averages and distributions for each community, real and predicted adjacency matrices

# %%
plot_ξ_distribution((g, l, k), q_model, q_codecs, adj, input_features)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

im1 = ax1.imshow(nx.adjacency_matrix(g).toarray())
ax1.set_title('Real adjacency matrix')
plt.colorbar(im1, ax=ax1)

x, _, feeds = next(batching.batches(vae, adj, input_features, target_func,
                                    adj.shape[0], 1,
                                    p=1, q=1, neighbour_samples=None))
adj_pred = vae.predict_on_fed_batch(x, feeds=feeds)[1]
im2 = ax2.imshow(scipy.special.expit(adj_pred[0]).mean(axis=0))
im2.set_norm(im1.norm)
ax2.set_title('Predicted adjacency matrix')
plt.colorbar(im2, ax=ax2);

# %% [markdown]
# **Train**

# %%
n_epochs = 5000
seeds_per_batch = n_nodes
max_walk_length = 1
p = 1
q = 1
neighbour_samples = None

steps_per_epoch = int(np.ceil(len(input_features) / seeds_per_batch))

# %%
history = vae.fit_generator_feed(batching.batches(vae, adj, input_features, target_func,
                                                  seeds_per_batch, max_walk_length,
                                                  p=p, q=q, neighbour_samples=neighbour_samples),
                                 steps_per_epoch=steps_per_epoch,
                                 epochs=n_epochs,
                                 check_array_lengths=False,
                                 shuffle=False,
                                 verbose=0,
                                 callbacks=[
                                     #keras.callbacks.TensorBoard(),
                                     #ae.ModelBatchCheckpoint(MODEL_NAME + '.batch-checkpoint.h5',
                                     #                        monitor='loss', period=10,
                                     #                        save_best_only=True),
                                     #keras.callbacks.ModelCheckpoint(MODEL_NAME + '.epoch-checkpoint.h5',
                                     #                                monitor='loss', period=10,
                                     #                                save_best_only=True),
                                     TQDMCallback(show_inner=False),
                                 ])
# Out:
# /home/sl/.conda/envs/base36/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:98: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /home/sl/.conda/envs/base36/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:98: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# HBox(children=(IntProgress(value=0, description='Training', max=5000), HTML(value='')))

# %% [markdown]
# Usually, the cell above complains with "UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.". See these for more details:
# * https://stackoverflow.com/questions/35892412/tensorflow-dense-gradient-explanation#35896823
# * https://stackoverflow.com/questions/39111373/tensorflow-chaining-tf-gather-produces-indexedslices-warning

# %% [markdown]
# ---
#
# ## Three feature communities, shifted from 8 network communities, plus .1 gaussian noise so that it can separate the nodes
#
# ```python
# labels = np.zeros((l * k, 3), dtype=np.float32)
# labels[:25, 0] = 1
# labels[25:55, 1] = 1
# labels[55:, 2] = 1
#
# noisy_labels = labels + np.random.normal(loc=0.0, scale=.1, size=labels.shape)
#
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(5, 5))
#
# im1 = ax1.imshow(labels)
# plt.colorbar(im1, ax=ax1)
#
# im2 = ax2.imshow(noisy_labels)
# plt.colorbar(im2, ax=ax2)
# ```
#
# **Loss weights 1, 1.999, .001.**
#
# The model separates the two types of labels on one axis, and whether nodes are connected or not into another axis.

# %%
x, _, feeds = next(batching.batches(vae, adj, input_features, target_func,
                                    adj.shape[0], 1,
                                    p=1, q=1, neighbour_samples=None))
q_preds, adj_preds, v_preds = vae.predict_on_fed_batch(x, feeds=feeds)

q_pred = q_preds
adj_pred = scipy.special.expit(adj_preds).mean(1)[0]
v_pred = scipy.special.expit(v_preds).mean(1)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(7, 5))

im1 = ax1.imshow(labels)
ax1.set_title('Real labels')
plt.colorbar(im1, ax=ax1)

im2 = ax2.imshow(input_features)
ax2.set_title('Input features')
plt.colorbar(im2, ax=ax2)

im3 = ax3.imshow(v_pred)
ax3.set_title('Reconstructed labels')
plt.colorbar(im3, ax=ax3)

# %%
fig, axes = plt.subplots(1, len(history.history), figsize=(len(history.history) * 5, 4))
for i, (title, values) in enumerate(history.history.items()):
    axes[i].plot(values)
    axes[i].set_title(title)
fig.tight_layout()

# %% [markdown]
# **After training:** $\xi$ averages and distributions for each community, real and predicted adjacency matrices

# %%
plot_ξ_distribution((g, l, k), q_model, q_codecs, adj, input_features)

# %% [markdown]
# Predicted adjacency matrix:

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

im1 = ax1.imshow(nx.adjacency_matrix(g).toarray())
ax1.set_title('Real adjacency matrix')
plt.colorbar(im1, ax=ax1)

im2 = ax2.imshow(adj_pred)
im2.set_norm(im1.norm)
ax2.set_title('Predicted adjacency matrix')
plt.colorbar(im2, ax=ax2);

# %% [markdown]
# ---
#
# ## Three feature communities, shifted from 8 network communities, plus .1 gaussian noise so that it can separate the nodes
#
# ```python
# labels = np.zeros((l * k, 3), dtype=np.float32)
# labels[:25, 0] = 1
# labels[25:55, 1] = 1
# labels[55:, 2] = 1
#
# noisy_labels = labels + np.random.normal(loc=0.0, scale=.1, size=labels.shape)
#
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(5, 5))
#
# im1 = ax1.imshow(labels)
# plt.colorbar(im1, ax=ax1)
#
# im2 = ax2.imshow(noisy_labels)
# plt.colorbar(im2, ax=ax2)
# ```
#
# **Loss weights 1, .001, 1.999.**
#
# The model separates the two types of labels on one axis, and whether nodes are connected or not into another axis.

# %%
x, _, feeds = next(batching.batches(vae, adj, input_features, target_func,
                                    adj.shape[0], 1,
                                    p=1, q=1, neighbour_samples=None))
q_preds, adj_preds, v_preds = vae.predict_on_fed_batch(x, feeds=feeds)

q_pred = q_preds
adj_pred = scipy.special.expit(adj_preds).mean(1)[0]
v_pred = scipy.special.expit(v_preds).mean(1)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(7, 5))

im1 = ax1.imshow(labels)
ax1.set_title('Real labels')
plt.colorbar(im1, ax=ax1)

im2 = ax2.imshow(input_features)
ax2.set_title('Input features')
plt.colorbar(im2, ax=ax2)

im3 = ax3.imshow(v_pred)
ax3.set_title('Reconstructed labels')
plt.colorbar(im3, ax=ax3)

# %%
fig, axes = plt.subplots(1, len(history.history), figsize=(len(history.history) * 5, 4))
for i, (title, values) in enumerate(history.history.items()):
    axes[i].plot(values)
    axes[i].set_title(title)
fig.tight_layout()

# %% [markdown]
# **After training:** $\xi$ averages and distributions for each community, real and predicted adjacency matrices

# %%
plot_ξ_distribution((g, l, k), q_model, q_codecs, adj, input_features)

# %% [markdown]
# Predicted adjacency matrix:

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

im1 = ax1.imshow(nx.adjacency_matrix(g).toarray())
ax1.set_title('Real adjacency matrix')
plt.colorbar(im1, ax=ax1)

im2 = ax2.imshow(adj_pred)
im2.set_norm(im1.norm)
ax2.set_title('Predicted adjacency matrix')
plt.colorbar(im2, ax=ax2);

# %% [markdown]
# ---
#
# ## Three feature communities, shifted from 8 network communities, plus .1 gaussian noise so that it can separate the nodes
#
# ```python
# labels = np.zeros((l * k, 3), dtype=np.float32)
# labels[:25, 0] = 1
# labels[25:55, 1] = 1
# labels[55:, 2] = 1
#
# noisy_labels = labels + np.random.normal(loc=0.0, scale=.1, size=labels.shape)
#
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(5, 5))
#
# im1 = ax1.imshow(labels)
# plt.colorbar(im1, ax=ax1)
#
# im2 = ax2.imshow(noisy_labels)
# plt.colorbar(im2, ax=ax2)
# ```
#
# Loss weights 1, 1, 1.
#
# The model separates the two types of labels on one axis, and whether nodes are connected or not into another axis.

# %%
x, _, feeds = next(batching.batches(vae, adj, input_features, target_func,
                                    adj.shape[0], 1,
                                    p=1, q=1, neighbour_samples=None))
q_preds, adj_preds, v_preds = vae.predict_on_fed_batch(x, feeds=feeds)

q_pred = q_preds
adj_pred = scipy.special.expit(adj_preds).mean(1)[0]
v_pred = scipy.special.expit(v_preds).mean(1)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(7, 5))

im1 = ax1.imshow(labels)
ax1.set_title('Real labels')
plt.colorbar(im1, ax=ax1)

im2 = ax2.imshow(input_features)
ax2.set_title('Input features')
plt.colorbar(im2, ax=ax2)

im3 = ax3.imshow(v_pred)
ax3.set_title('Reconstructed labels')
plt.colorbar(im3, ax=ax3)

# %%
fig, axes = plt.subplots(1, len(history.history), figsize=(len(history.history) * 5, 4))
for i, (title, values) in enumerate(history.history.items()):
    axes[i].plot(values)
    axes[i].set_title(title)
fig.tight_layout()

# %%
fig, axes = plt.subplots(1, len(history.history), figsize=(len(history.history) * 5, 4))
for i, (title, values) in enumerate(history.history.items()):
    axes[i].plot(values)
    axes[i].set_title(title)
fig.tight_layout()

# %% [markdown]
# **After training:** $\xi$ averages and distributions for each community, real and predicted adjacency matrices

# %%
plot_ξ_distribution((g, l, k), q_model, q_codecs, adj, input_features)

# %% [markdown]
# Predicted adjacency matrix:

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

im1 = ax1.imshow(nx.adjacency_matrix(g).toarray())
ax1.set_title('Real adjacency matrix')
plt.colorbar(im1, ax=ax1)

im2 = ax2.imshow(adj_pred)
im2.set_norm(im1.norm)
ax2.set_title('Predicted adjacency matrix')
plt.colorbar(im2, ax=ax2);

# %% [markdown]
# ---
#
# ## Communities 1, 2 and half of community 3 have 1 or 2 random ones, the rest of community 3, and communities 4, 5 have another 1 or 2 random ones, all this plus .1 gaussian noise so that it can separate the nodes
#
# ```python
# labels = np.zeros((l * k, l), dtype=np.float32)
# ids1 = np.random.choice(range(l), 2)
# ids2 = np.random.choice(range(l), 2)
# labels[list(zip(*itertools.product(range(int(k * 2.5)), ids1)))] = 1
# labels[list(zip(*itertools.product(range(int(k * 2.5), l * k), ids2)))] = 1
#
# noisy_labels = labels + np.random.normal(loc=0.0, scale=.1, size=labels.shape)
#
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(5, 5))
#
# im1 = ax1.imshow(labels)
# plt.colorbar(im1, ax=ax1)
#
# im2 = ax2.imshow(noisy_labels)
# plt.colorbar(im2, ax=ax2)
# ```
#
# Loss weights 1, 1, 1.
#
# The model separates the two types of labels on one axis, and whether nodes are connected or not into another axis.

# %%
x, _, feeds = next(batching.batches(vae, adj, input_features, target_func,
                                    adj.shape[0], 1,
                                    p=1, q=1, neighbour_samples=None))
q_preds, adj_preds, v_preds = vae.predict_on_fed_batch(x, feeds=feeds)

q_pred = q_preds
adj_pred = scipy.special.expit(adj_preds).mean(1)[0]
v_pred = scipy.special.expit(v_preds).mean(1)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(7, 5))

im1 = ax1.imshow(labels)
ax1.set_title('Real labels')
plt.colorbar(im1, ax=ax1)

im2 = ax2.imshow(input_features)
ax2.set_title('Input features')
plt.colorbar(im2, ax=ax2)

im3 = ax3.imshow(v_pred)
ax3.set_title('Reconstructed labels')
plt.colorbar(im3, ax=ax3)

# %%
fig, axes = plt.subplots(1, len(history.history), figsize=(len(history.history) * 5, 4))
for i, (title, values) in enumerate(history.history.items()):
    axes[i].plot(values)
    axes[i].set_title(title)
fig.tight_layout()

# %% [markdown]
# **After training:** $\xi$ averages and distributions for each community, real and predicted adjacency matrices

# %%
plot_ξ_distribution((g, l, k), q_model, q_codecs, adj, input_features)

# %% [markdown]
# Predicted adjacency matrix:

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

im1 = ax1.imshow(nx.adjacency_matrix(g).toarray())
ax1.set_title('Real adjacency matrix')
plt.colorbar(im1, ax=ax1)

im2 = ax2.imshow(adj_pred)
im2.set_norm(im1.norm)
ax2.set_title('Predicted adjacency matrix')
plt.colorbar(im2, ax=ax2);

# %% [markdown]
# ---
#
# ## Communities 1 and 2 have 1 or 2 random ones, communities 3, 4, 5 have another 2 random ones
#
# Loss weights 1, 1, 1

# %%
plt.imshow(labels)

# %%
fig, axes = plt.subplots(1, len(history.history), figsize=(len(history.history) * 5, 4))
for i, (title, values) in enumerate(history.history.items()):
    axes[i].plot(values)
    axes[i].set_title(title)
fig.tight_layout()

# %% [markdown]
# **After training:** $\xi$ averages and distributions for each community, real and predicted adjacency matrices

# %%
plot_ξ_distribution((g, l, k), q_model, adj, features)

# %% [markdown]
# Predicted adjacency matrix:

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

im1 = ax1.imshow(nx.adjacency_matrix(g).todense())
ax1.set_title('Real adjacency matrix')
plt.colorbar(im1, ax=ax1)

x, _, feeds = next(batching.batches(vae, adj, features, target_func,
                                    adj.shape[0], 1,
                                    p=1, q=1, neighbour_samples=None))
adj_pred = vae.predict_on_fed_batch(x, feeds=feeds)[1]
im2 = ax2.imshow(scipy.special.expit(adj_pred[0].mean(axis=0)))
im2.set_norm(im1.norm)
ax2.set_title('Predicted adjacency matrix')
plt.colorbar(im2, ax=ax2);

# %% [markdown]
# ---
#
# ## 1 or 2 random ones for each half-community
#
# Loss weights 1, 1, 1

# %%
plt.imshow(labels)

# %%
fig, axes = plt.subplots(1, len(history.history), figsize=(len(history.history) * 5, 4))
for i, (title, values) in enumerate(history.history.items()):
    axes[i].plot(values)
    axes[i].set_title(title)
fig.tight_layout()

# %% [markdown]
# **After training:** $\xi$ averages and distributions for each community, real and predicted adjacency matrices

# %%
plot_ξ_distribution((g, l, k), q_model, adj, features)

# %% [markdown]
# Predicted adjacency matrix:

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

im1 = ax1.imshow(nx.adjacency_matrix(g).todense())
ax1.set_title('Real adjacency matrix')
plt.colorbar(im1, ax=ax1)

x, _, feeds = next(batching.batches(vae, adj, features, target_func,
                                    adj.shape[0], 1,
                                    p=1, q=1, neighbour_samples=None))
adj_pred = vae.predict_on_fed_batch(x, feeds=feeds)[1]
im2 = ax2.imshow(scipy.special.expit(adj_pred[0].mean(axis=0)))
im2.set_norm(im1.norm)
ax2.set_title('Predicted adjacency matrix')
plt.colorbar(im2, ax=ax2);

# %% [markdown]
# ---
#
# ## 1 or 2 random ones for each community
#
# Loss weights 1, 1, 1

# %%
plt.imshow(labels)

# %%
fig, axes = plt.subplots(1, len(history.history), figsize=(len(history.history) * 5, 4))
for i, (title, values) in enumerate(history.history.items()):
    axes[i].plot(values)
    axes[i].set_title(title)
fig.tight_layout()

# %% [markdown]
# **After training:** $\xi$ averages and distributions for each community, real and predicted adjacency matrices

# %%
plot_ξ_distribution((g, l, k), q_model, adj, features)

# %% [markdown]
# Predicted adjacency matrix:

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

im1 = ax1.imshow(nx.adjacency_matrix(g).todense())
ax1.set_title('Real adjacency matrix')
plt.colorbar(im1, ax=ax1)

x, _, feeds = next(batching.batches(vae, adj, features, target_func,
                                    adj.shape[0], 1,
                                    p=1, q=1, neighbour_samples=None))
adj_pred = vae.predict_on_fed_batch(x, feeds=feeds)[1]
im2 = ax2.imshow(scipy.special.expit(adj_pred[0].mean(axis=0)))
im2.set_norm(im1.norm)
ax2.set_title('Predicted adjacency matrix')
plt.colorbar(im2, ax=ax2);

# %% [markdown]
# ---
#
# ## One-hot encoding finer than the network structure
#
# Loss weights 1, 1, 1

# %%
plt.imshow(labels)

# %%
fig, axes = plt.subplots(1, len(history.history), figsize=(len(history.history) * 5, 4))
for i, (title, values) in enumerate(history.history.items()):
    axes[i].plot(values)
    axes[i].set_title(title)
fig.tight_layout()

# %% [markdown]
# **After training:** $\xi$ averages and distributions for each community, real and predicted adjacency matrices

# %%
plot_ξ_distribution((g, l, k), q_model, adj, features)

# %% [markdown]
# Predicted adjacency matrix:

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

im1 = ax1.imshow(nx.adjacency_matrix(g).todense())
ax1.set_title('Real adjacency matrix')
plt.colorbar(im1, ax=ax1)

x, _, feeds = next(batching.batches(vae, adj, features, target_func,
                                    adj.shape[0], 1,
                                    p=1, q=1, neighbour_samples=None))
adj_pred = vae.predict_on_fed_batch(x, feeds=feeds)[1]
im2 = ax2.imshow(scipy.special.expit(adj_pred[0].mean(axis=0)))
im2.set_norm(im1.norm)
ax2.set_title('Predicted adjacency matrix')
plt.colorbar(im2, ax=ax2);

# %% [markdown]
# ---
#
# ## One-hot encoding shifted from the network structure
#
# Loss weights 1, 1, 1

# %%
plt.imshow(labels)

# %%
fig, axes = plt.subplots(1, len(history.history), figsize=(len(history.history) * 5, 4))
for i, (title, values) in enumerate(history.history.items()):
    axes[i].plot(values)
    axes[i].set_title(title)
fig.tight_layout()

# %% [markdown]
# **After training:** $\xi$ averages and distributions for each community, real and predicted adjacency matrices

# %%
plot_ξ_distribution((g, l, k), q_model, adj, features)

# %% [markdown]
# Predicted adjacency matrix:

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

im1 = ax1.imshow(nx.adjacency_matrix(g).todense())
ax1.set_title('Real adjacency matrix')
plt.colorbar(im1, ax=ax1)

x, _, feeds = next(batching.batches(vae, adj, features, target_func,
                                    adj.shape[0], 1,
                                    p=1, q=1, neighbour_samples=None))
adj_pred = vae.predict_on_fed_batch(x, feeds=feeds)[1]
im2 = ax2.imshow(scipy.special.expit(adj_pred[0].mean(axis=0)))
im2.set_norm(im1.norm)
ax2.set_title('Predicted adjacency matrix')
plt.colorbar(im2, ax=ax2);

# %% [markdown]
# ---
#
# ## All nodes have 1 or 2 random features at 1, the rest at 0
#
# Loss weights 1, 1, 1

# %%
plt.imshow(labels)

# %%
fig, axes = plt.subplots(1, len(history.history), figsize=(len(history.history) * 5, 4))
for i, (title, values) in enumerate(history.history.items()):
    axes[i].plot(values)
    axes[i].set_title(title)
fig.tight_layout()

# %% [markdown]
# **After training:** $\xi$ averages and distributions for each community, real and predicted adjacency matrices

# %%
plot_ξ_distribution((g, l, k), q_model, adj, features)

# %% [markdown]
# Predicted adjacency matrix:

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

im1 = ax1.imshow(nx.adjacency_matrix(g).todense())
ax1.set_title('Real adjacency matrix')
plt.colorbar(im1, ax=ax1)

x, _, feeds = next(batching.batches(vae, adj, features, target_func,
                                    adj.shape[0], 1,
                                    p=1, q=1, neighbour_samples=None))
adj_pred = vae.predict_on_fed_batch(x, feeds=feeds)[1]
im2 = ax2.imshow(scipy.special.expit(adj_pred[0].mean(axis=0)))
im2.set_norm(im1.norm)
ax2.set_title('Predicted adjacency matrix')
plt.colorbar(im2, ax=ax2);

# %% [markdown]
# ---
#
# ## Communities 1, 2, and half of 3 have `[1, 0, 0, 0, 0]`, other half of 3, and 4, 5 have `[0, 1, 0, 0, 0]`
#
# Loss weights 1, 1, 1

# %%
plt.imshow(labels)

# %%
fig, axes = plt.subplots(1, len(history.history), figsize=(len(history.history) * 5, 4))
for i, (title, values) in enumerate(history.history.items()):
    axes[i].plot(values)
    axes[i].set_title(title)
fig.tight_layout()

# %% [markdown]
# **After training:** $\xi$ averages and distributions for each community, real and predicted adjacency matrices

# %%
plot_ξ_distribution((g, l, k), q_model, adj, features)

# %% [markdown]
# Predicted adjacency matrix:

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

im1 = ax1.imshow(nx.adjacency_matrix(g).todense())
ax1.set_title('Real adjacency matrix')
plt.colorbar(im1, ax=ax1)

x, _, feeds = next(batching.batches(vae, adj, features, target_func,
                                    adj.shape[0], 1,
                                    p=1, q=1, neighbour_samples=None))
adj_pred = vae.predict_on_fed_batch(x, feeds=feeds)[1]
im2 = ax2.imshow(scipy.special.expit(adj_pred[0].mean(axis=0)))
im2.set_norm(im1.norm)
ax2.set_title('Predicted adjacency matrix')
plt.colorbar(im2, ax=ax2);

# %% [markdown]
# ---
#
# ## Communities 1 & 2 have `[1, 0, 0, 0, 0]` + `eye`, comms 3, 4, 5 have `[0, 1, 0, 0, 0]` + `eye`
#
# Loss weights 1, 1, 1

# %%
plt.imshow(labels)

# %%
fig, axes = plt.subplots(1, len(history.history), figsize=(len(history.history) * 5, 4))
for i, (title, values) in enumerate(history.history.items()):
    axes[i].plot(values)
    axes[i].set_title(title)
fig.tight_layout()

# %% [markdown]
# **After training:** $\xi$ averages and distributions for each community, real and predicted adjacency matrices

# %%
plot_ξ_distribution((g, l, k), q_model, adj, features)

# %% [markdown]
# Predicted adjacency matrix:

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

im1 = ax1.imshow(nx.adjacency_matrix(g).todense())
ax1.set_title('Real adjacency matrix')
plt.colorbar(im1, ax=ax1)

x, _, feeds = next(batching.batches(vae, adj, features, target_func,
                                    adj.shape[0], 1,
                                    p=1, q=1, neighbour_samples=None))
adj_pred = vae.predict_on_fed_batch(x, feeds=feeds)[1]
im2 = ax2.imshow(scipy.special.expit(adj_pred[0].mean(axis=0)))
im2.set_norm(im1.norm)
ax2.set_title('Predicted adjacency matrix')
plt.colorbar(im2, ax=ax2);

# %% [markdown]
# ---
#
# ## Communities 1 & 2 have `[1, 0, 0, 0, 0]`, comms 3, 4, 5 have `[0, 1, 0, 0, 0]`
#
# Loss weights 1, 10, 1

# %%
plt.imshow(labels)

# %%
fig, axes = plt.subplots(1, len(history.history), figsize=(len(history.history) * 5, 4))
for i, (title, values) in enumerate(history.history.items()):
    axes[i].plot(values)
    axes[i].set_title(title)
fig.tight_layout()

# %% [markdown]
# **After training:** $\xi$ averages and distributions for each community, real and predicted adjacency matrices

# %%
plot_ξ_distribution((g, l, k), q_model, adj, features)

# %% [markdown]
# Predicted adjacency matrix:

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

im1 = ax1.imshow(nx.adjacency_matrix(g).todense())
ax1.set_title('Real adjacency matrix')
plt.colorbar(im1, ax=ax1)

x, _, feeds = next(batching.batches(vae, adj, features, target_func,
                                    adj.shape[0], 1,
                                    p=1, q=1, neighbour_samples=None))
adj_pred = vae.predict_on_fed_batch(x, feeds=feeds)[1]
im2 = ax2.imshow(scipy.special.expit(adj_pred[0].mean(axis=0)))
im2.set_norm(im1.norm)
ax2.set_title('Predicted adjacency matrix')
plt.colorbar(im2, ax=ax2);

# %% [markdown]
# ---
#
# ## Communities 1 & 2 have `[1, 0, 0, 0, 0]`, comms 3, 4, 5 have `[0, 1, 0, 0, 0]`
#
# Loss weights 1, 1, 1

# %%
labels = np.zeros((l * k, l), dtype=np.float32)
labels[:2 * k, 0] = 1
labels[2 * k:, 1] = 1
plt.imshow(labels)

# %%
fig, axes = plt.subplots(1, len(history.history), figsize=(len(history.history) * 5, 4))
for i, (title, values) in enumerate(history.history.items()):
    axes[i].plot(values)
    axes[i].set_title(title)
fig.tight_layout()

# %% [markdown]
# **After training:** $\xi$ averages and distributions for each community, real and predicted adjacency matrices

# %%
plot_ξ_distribution((g, l, k), q_model, adj, features)

# %% [markdown]
# Predicted adjacency matrix:

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

im1 = ax1.imshow(nx.adjacency_matrix(g).todense())
ax1.set_title('Real adjacency matrix')
plt.colorbar(im1, ax=ax1)

x, _, feeds = next(batching.batches(vae, adj, features, target_func,
                                    adj.shape[0], 1,
                                    p=1, q=1, neighbour_samples=None))
adj_pred = vae.predict_on_fed_batch(x, feeds=feeds)[1]
im2 = ax2.imshow(scipy.special.expit(adj_pred[0].mean(axis=0)))
im2.set_norm(im1.norm)
ax2.set_title('Predicted adjacency matrix')
plt.colorbar(im2, ax=ax2);
