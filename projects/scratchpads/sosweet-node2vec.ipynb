# %% [markdown]
# # node2vec on the SoSweet mention network

# %%
import logging

# utilities and plotting
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# node2vec stuff
import jwalk
from gensim.models import Word2Vec

from nw2vec import utils

logging.basicConfig(level=logging.INFO)

# %%
WEIGHTED_NETWORK_FILES = [
    #'dir_weighted_mention_network.txt',
    #'dir_weighted_mention_network_thresh_5.txt',
    'undir_weighted_mention_network_thresh_5.txt',
]

# %% [markdown]
# Compute SoSweet embeddings

# %%
sosweet_embfiles = {}
for netfile in WEIGHTED_NETWORK_FILES:
    sosweet_embfiles[netfile] = utils.node2vec('datasets/sosweet-network/' + netfile,
                                               'datasets/sosweet-network/' + netfile[:-4] + '.emb',
                                               num_walks=10, embedding_size=50, window_size=10,
                                               walk_length=80, workers=40, undirected=False)
# Out:
# INFO:nw2vec.utils:Loading edges from data/sosweet-network/undir_weighted_mention_network_thresh_5.txt
# INFO:nw2vec.utils:Building adjacency matrix
# INFO:nw2vec.utils:Saving graph to data/sosweet-network/undir_weighted_mention_network_thresh_5.txt.npz
# INFO:nw2vec.utils:Doing 10 random walks of length 80
# INFO:nw2vec.utils:Building corpus from walks
# INFO:nw2vec.utils:Running Word2Vec on corpus
# WARNING:gensim.models.word2vec:consider setting layer size to a multiple of 4 for greater performance
# INFO:gensim.models.word2vec:Loading a fresh vocabulary
# INFO:gensim.models.word2vec:min_count=1 retains 178359 unique words (100% of original 178359, drops 0)
# INFO:gensim.models.word2vec:min_count=1 leaves 5244790 word corpus (100% of original 5244790, drops 0)
# INFO:gensim.models.word2vec:deleting the raw counts dictionary of 178359 items
# INFO:gensim.models.word2vec:sample=0.001 downsamples 0 most-common words
# ...
