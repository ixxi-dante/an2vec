# %% [markdown]
# # GAE benchmark results

# %%
import glob
from collections import defaultdict
import re

import numpy as np
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# ## AN2VEC

# %%
results = defaultdict(list)
pattern = re.compile("bias=([^-/]+)-l1=([^-]+)-decadj=([^-]+)/([^-/]+)-overlap=([^-]+)-blurring=([^-]+)-sample=([^-]+).npz")

for fname in glob.glob("../data/behaviour/gae-benchmarks/*/*.npz"):
    research = re.search(pattern, fname)
    if research is None:
        print("No match: {}".format(fname))
        continue
    bias, l1, decadj, dataset, overlap, blurring, sample = research.groups()
    results['bias'].append(bias)
    results['l1'].append(l1)
    results['decadj'].append(decadj)
    results['dataset'].append(dataset)
    results['overlap'].append(int(overlap))
    results['blurring'].append(float(blurring))
    results['sample'].append(int(sample))
    history = np.load(fname)
    for k, v in history.items():
        results['final {}'.format(k)].append(v[-1])

results = pd.DataFrame(results)
# Out:
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.30-sample=3.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.30-sample=5.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.30-sample=7.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.30-sample=4.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.15-sample=6.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.15-sample=8.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.30-sample=4.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.15-sample=4.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.30-sample=6.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.30-sample=8.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.30-sample=5.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.30-sample=1.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.30-sample=6.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.30-sample=10.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.15-sample=9.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.15-sample=5.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.30-sample=3.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.30-sample=8.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.30-sample=10.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.15-sample=3.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.15-sample=8.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.15-sample=9.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.15-sample=10.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.30-sample=2.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.30-sample=1.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.15-sample=6.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.30-sample=6.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.15-sample=6.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.15-sample=5.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.30-sample=5.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.15-sample=2.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.15-sample=10.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.15-sample=1.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.15-sample=10.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.30-sample=9.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.15-sample=2.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.15-sample=7.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.15-sample=4.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.15-sample=7.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.30-sample=8.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.15-sample=5.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.15-sample=1.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.15-sample=7.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.30-sample=2.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.15-sample=1.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.30-sample=10.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.30-sample=2.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.15-sample=3.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.15-sample=8.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.30-sample=4.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.30-sample=7.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.30-sample=9.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.15-sample=9.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.30-sample=7.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.30-sample=9.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.30-sample=1.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/cora-blurring=0.15-sample=3.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/pubmed-blurring=0.15-sample=4.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.15-sample=2.npz
# No match: ../data/behaviour/gae-benchmarks/julia-vgae/citeseer-blurring=0.30-sample=3.npz

# %%
averages = results.groupby(['bias', 'l1', 'decadj', 'dataset', 'overlap', 'blurring']).mean()
stds = results.groupby(['bias', 'l1', 'decadj', 'dataset', 'overlap', 'blurring']).std()

# %% [markdown]
# ### Shared l1

# %%
averages.xs(['no', 'shared'])\
    [['final auc', 'final ap']]\
    .stack().unstack([1, 4])\
    .reorder_levels(['blurring', 'decadj', 'overlap']).sort_index()\
    [['cora', 'citeseer', 'pubmed']]
# Out:
# dataset                       cora            citeseer              pubmed  \
#                          final auc  final ap final auc  final ap final auc
# blurring decadj  overlap
# 0.15     deep    0        0.894966  0.906183  0.911738  0.914969  0.917656
#                  8        0.894163  0.901655  0.906675  0.913345  0.918967
#                  16       0.894432  0.901691  0.910926  0.913118  0.920825
#          shallow 0        0.928682  0.933899  0.943383  0.947583  0.950613
#                  8        0.927322  0.934120  0.939979  0.945119  0.946433
#                  16       0.929577  0.935055  0.948636  0.951210  0.930713
# 0.30     deep    0        0.870261  0.883763  0.900240  0.907128       NaN
#                  8        0.873925  0.884422  0.906741  0.912850       NaN
#                  16       0.874988  0.885477  0.904020  0.909247       NaN
#          shallow 0        0.917483  0.926492  0.934818  0.941006       NaN
#                  8        0.913348  0.921670  0.936631  0.941236       NaN
#                  16       0.922110  0.929991  0.941263  0.946137       NaN
#
# dataset
#                           final ap
# blurring decadj  overlap
# 0.15     deep    0        0.931821
#                  8        0.930725
#                  16       0.927513
#          shallow 0        0.953707
#                  8        0.948626
#                  16       0.930576
# 0.30     deep    0             NaN
#                  8             NaN
#                  16            NaN
#          shallow 0             NaN
#                  8             NaN
#                  16            NaN

# %%
stds.xs(['no', 'shared'])\
    [['final auc', 'final ap']]\
    .stack().unstack([1, 4])\
    .reorder_levels(['blurring', 'decadj', 'overlap']).sort_index()\
    [['cora', 'citeseer', 'pubmed']]
# Out:
# dataset                       cora            citeseer              pubmed  \
#                          final auc  final ap final auc  final ap final auc
# blurring decadj  overlap
# 0.15     deep    0        0.008958  0.010085  0.011823  0.016050  0.006894
#                  8        0.008919  0.009641  0.014928  0.013950  0.004525
#                  16       0.009929  0.008825  0.012307  0.015842  0.009610
#          shallow 0        0.009517  0.008939  0.007970  0.008259  0.006221
#                  8        0.005814  0.006550  0.005179  0.006903  0.005213
#                  16       0.005445  0.004146  0.003144  0.004081  0.006167
# 0.30     deep    0        0.008703  0.007871  0.006552  0.007969       NaN
#                  8        0.006800  0.007201  0.009225  0.009153       NaN
#                  16       0.004632  0.006397  0.012256  0.014186       NaN
#          shallow 0        0.003839  0.003894  0.004883  0.004365       NaN
#                  8        0.003352  0.002935  0.003570  0.004171       NaN
#                  16       0.005105  0.005149  0.003933  0.004010       NaN
#
# dataset
#                           final ap
# blurring decadj  overlap
# 0.15     deep    0        0.005810
#                  8        0.004613
#                  16       0.009229
#          shallow 0        0.005054
#                  8        0.004407
#                  16       0.005951
# 0.30     deep    0             NaN
#                  8             NaN
#                  16            NaN
#          shallow 0             NaN
#                  8             NaN
#                  16            NaN

# %% [markdown]
# ### Unshared l1

# %%
averages.xs(['no', 'unshared'])\
    [['final auc', 'final ap']]\
    .stack().unstack([1, 4])\
    .reorder_levels(['blurring', 'decadj', 'overlap']).sort_index()\
    [['cora', 'citeseer', 'pubmed']]
# Out:
# dataset                       cora            citeseer              pubmed  \
#                          final auc  final ap final auc  final ap final auc
# blurring decadj  overlap
# 0.15     deep    0        0.878889  0.889161  0.883669  0.896437  0.911545
#                  8        0.888567  0.898379  0.906347  0.913059  0.924394
#                  16       0.900028  0.905909  0.920655  0.925727  0.927221
#          shallow 0        0.923319  0.928662  0.921044  0.927855  0.965680
#                  8        0.927526  0.935292  0.938072  0.946153  0.957962
#                  16       0.929430  0.935574  0.952907  0.957464  0.935675
# 0.30     deep    0        0.857324  0.871324  0.878582  0.888778       NaN
#                  8        0.866786  0.880621  0.895065  0.901866       NaN
#                  16       0.877342  0.890497  0.909668  0.913283       NaN
#          shallow 0        0.907103  0.917110  0.912482  0.921022       NaN
#                  8        0.915119  0.925525  0.932313  0.939822       NaN
#                  16       0.923395  0.930320  0.947187  0.952175       NaN
#
# dataset
#                           final ap
# blurring decadj  overlap
# 0.15     deep    0        0.928493
#                  8        0.936358
#                  16       0.934089
#          shallow 0        0.969072
#                  8        0.959257
#                  16       0.937016
# 0.30     deep    0             NaN
#                  8             NaN
#                  16            NaN
#          shallow 0             NaN
#                  8             NaN
#                  16            NaN

# %%
stds.xs(['no', 'unshared'])\
    [['final auc', 'final ap']]\
    .stack().unstack([1, 4])\
    .reorder_levels(['blurring', 'decadj', 'overlap']).sort_index()\
    [['cora', 'citeseer', 'pubmed']]
# Out:
# dataset                       cora            citeseer              pubmed  \
#                          final auc  final ap final auc  final ap final auc
# blurring decadj  overlap
# 0.15     deep    0        0.011553  0.013227  0.017393  0.013937  0.006618
#                  8        0.006075  0.006148  0.015170  0.014720  0.002993
#                  16       0.008508  0.010280  0.006499  0.009107  0.005223
#          shallow 0        0.005052  0.007838  0.011416  0.010194  0.002308
#                  8        0.005166  0.005822  0.005360  0.005102  0.003672
#                  16       0.008018  0.006521  0.004613  0.004689  0.006327
# 0.30     deep    0        0.009080  0.009762  0.008169  0.005411       NaN
#                  8        0.006763  0.005230  0.010512  0.018303       NaN
#                  16       0.005353  0.006066  0.008169  0.012247       NaN
#          shallow 0        0.007691  0.007410  0.003531  0.003427       NaN
#                  8        0.005617  0.004569  0.004622  0.003685       NaN
#                  16       0.006861  0.005890  0.004498  0.004127       NaN
#
# dataset
#                           final ap
# blurring decadj  overlap
# 0.15     deep    0        0.005229
#                  8        0.002054
#                  16       0.005234
#          shallow 0        0.002260
#                  8        0.003106
#                  16       0.007203
# 0.30     deep    0             NaN
#                  8             NaN
#                  16            NaN
#          shallow 0             NaN
#                  8             NaN
#                  16            NaN

# %% [markdown]
# ## VGAE

# %%
results_vgae = defaultdict(list)
pattern_vgae = re.compile("([^-/]+)-blurring=([^-]+)-sample=([^-]+).npz")

for fname in glob.glob("../data/behaviour/gae-benchmarks/julia-vgae/*.npz"):
    research = re.search(pattern_vgae, fname)
    if research is None:
        print("No match: {}".format(fname))
        continue
    dataset, blurring, sample = research.groups()
    results_vgae['dataset'].append(dataset)
    results_vgae['blurring'].append(float(blurring))
    results_vgae['sample'].append(int(sample))
    history = np.load(fname)
    for k, v in history.items():
        results_vgae['final {}'.format(k)].append(v[-1])

results_vgae = pd.DataFrame(results_vgae)

# %%
averages_vgae = results_vgae.groupby(['dataset', 'blurring']).mean()
stds_vgae = results_vgae.groupby(['dataset', 'blurring']).std()

# %%
averages_vgae[['final auc', 'final ap']].stack().unstack([0, 2])[['cora', 'citeseer', 'pubmed']]
# Out:
# dataset       cora            citeseer              pubmed
#          final auc  final ap final auc  final ap final auc  final ap
# blurring
# 0.15      0.922591  0.928798  0.921745  0.930244  0.965447  0.968721
# 0.30      0.902977  0.913436  0.911954  0.919151  0.961535  0.964560

# %%
stds_vgae[['final auc', 'final ap']].stack().unstack([0, 2])[['cora', 'citeseer', 'pubmed']]
# Out:
# dataset       cora            citeseer              pubmed
#          final auc  final ap final auc  final ap final auc  final ap
# blurring
# 0.15      0.005550  0.005833  0.006499  0.006631  0.001501  0.001229
# 0.30      0.004795  0.004589  0.005465  0.005182  0.001503  0.001434
